# %%
import cv2

# %%
# question 1 :
ret, frame = cap.read() # explain this to me , what are these two variables that are being returned by cap.read() function ?
# and before that what exactly is the .read() function do ?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # question 1 :
# ----> 2 ret, frame = cap.read() # explain this to me , what are these two variables that are being returned by cap.read() function ?
#       3 # and before that what exactly is the .read() function do ?
#
# NameError: name 'cap' is not defined
